# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# # Data Preprocessing

# %%
plt.scatter(x='CRIM',y='MEDV',data=data)

# %% [markdown]
# ### Drop rows with NaN

# %%
data.dropna(subset=['CRIM', 'MEDV'])
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 506  0.98765   0.0  12.50     0  0.561  6.980  89.0  2.0980    3  320
# 507  0.23456   0.0  12.50     0  0.561  6.980  76.0  2.6540    3  320
# 508  0.44433   0.0  12.50     0  0.561  6.123  98.0  2.9870    3  320
# 509  0.77763   0.0  12.70     0  0.561  6.222  34.0  2.5430    3  329
# 510  0.65432   0.0  12.80     0  0.561  6.760  67.0  2.9870    3  345
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ### Five Number Summary: Determine Outliers

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  511.000000  511.000000  511.000000  511.000000  511.000000  506.000000
# mean     3.584139   11.252446   11.151096    0.068493    0.554757    6.287589
# std      8.564433   23.234838    6.828175    0.252838    0.115310    0.703802
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082325    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.261690    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.621175   12.500000   18.100000    0.000000    0.624000    6.629750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  511.000000  511.000000  511.000000  511.000000  511.000000  511.000000
# mean    68.616243    3.783876    9.485323  407.440313   18.500000  356.600900
# ...

# %%
# An outlier, x, is greater than the upper quartile + 1.5 X IQR
# An outlier, x is less than lower quartile - 1.5 x IQR

Q3 = 25.000000	
Q1 = 17.050000
IQR = Q3 - Q1
upper_outlier = Q3 + 1.5 * IQR
lower_outlier = Q1 - 1.5 * IQR

# remove the outliers from the data
outlier = data.query("MEDV > @upper_outlier or MEDV < @lower_outlier") 
outlier
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD  TAX  \
# 97    0.12083   0.0   2.89     0  0.4450  8.069   76.0  3.4952    2  276
# 98    0.08187   0.0   2.89     0  0.4450  7.820   36.9  3.4952    2  276
# 157   1.22358   0.0  19.58     0  0.6050  6.943   97.4  1.8773    5  403
# 161   1.46336   0.0  19.58     0  0.6050  7.489   90.8  1.9709    5  403
# 162   1.83377   0.0  19.58     1  0.6050  7.802   98.2  2.0407    5  403
# 163   1.51902   0.0  19.58     1  0.6050  8.375   93.9  2.1620    5  403
# 166   2.01019   0.0  19.58     0  0.6050  7.929   96.2  2.0459    5  403
# 179   0.05780   0.0   2.46     0  0.4880  6.980   58.4  2.8290    3  193
# 180   0.06588   0.0   2.46     0  0.4880  7.765   83.3  2.7410    3  193
# 182   0.09103   0.0   2.46     0  0.4880  7.155   92.2  2.7006    3  193
# 186   0.05602   0.0   2.46     0  0.4880  7.831   53.6  3.1992    3  193
# 190   0.09068  45.0   3.44     0  0.4370  6.951   21.5  6.4798    5  398
# ...

# %%
wo_outlier = data.drop(labels=outlier.index)
wo_outlier
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
# 506  0.98765   0.0  12.50     0  0.561  6.980  89.0  2.0980    3  320
# 507  0.23456   0.0  12.50     0  0.561  6.980  76.0  2.6540    3  320
# 510  0.65432   0.0  12.80     0  0.561  6.760  67.0  2.9870    3  345
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
plt.scatter(x=wo_outlier.CRIM, y=wo_outlier.MEDV)
plt.xlabel('CRIM')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')
